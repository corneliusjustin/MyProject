# %%
import pandas as pd
import numpy as np
import re
from sklearn.model_selection import train_test_split
from tensorflow import keras
from transformers import AutoTokenizer, TFAutoModel, TFBertModel
from tensorflow.compat.v1.keras.layers import CuDNNLSTM
import IPython

# %%
# GET the data
## Memuat Data

dataset = pd.read_csv("/content/Capres2014-1.1.csv", usecols=["Isi_Tweet", "Sentimen"])

# %%
# EXPLORE the data
## Menampilkan lima data terakhir
dataset.tail()
# Out:
#                                               Isi_Tweet  Sentimen
# 1880  Jangan kabur dari tanggung jawab dengan kemasa...         1
# 1881  @echo_hadiwibowo mana berani pmrntah..m G da y...         1
# 1882  @IndonesiaCapres ANAK MEDAN DUKUNG CAPRES JK D...         1
# 1883  RT @idoidonajib: Jelek! "@fallenokta: Apa komp...         1
# 1884  Langsung deh ngadu ke capres Hatta Rajasa, bia...         1

# %%
## Mengecek Imbalanced Data
dataset['Sentimen'].value_counts()
# Out:
#  1    1117
# -1     768
# Name: Sentimen, dtype: int64

# %%
## Mengganti {-1,1} menjadi {0,1}
dataset['Sentimen'] = dataset['Sentimen'].replace(-1,0)

dataset['Sentimen'].value_counts()
# Out:
# 1    1117
# 0     768
# Name: Sentimen, dtype: int64

# %%
# MODEL the data
## Pra Pengolahan - Cleaning

def clean_text(tweet):
    
    # Convert to lower case
    tweet = tweet.lower()
    # remove unicode characters
    tweet = tweet.encode('ascii', 'ignore').decode()
    # Clean www.* or https?://*
    tweet = re.sub(r'((www\.[^\s]+)|(https?://[^\s]+))','',tweet)
    # Clean @username
    tweet = re.sub(r'@[^\s]+','',tweet)
    #Remove additional white spaces
    tweet = re.sub(r'[\s]+', ' ', tweet)
    #Replace #word with word
    tweet = re.sub(r'#([^\s]+)', r'\1', tweet)
    
    #trim
    tweet = tweet.strip('\'"')
    
    return tweet

dataset["Isi_Tweet"] = dataset['Isi_Tweet'].map(lambda x: clean_text(x))
dataset = dataset[dataset['Isi_Tweet'].apply(lambda x: len(x.split()) >=1)]
dataset.shape
# Out:
# (1885, 2)

# %%
## Pra Pengolahan - Splitting

train_data, test_data, train_labels, test_labels = train_test_split(
    dataset['Isi_Tweet'], dataset['Sentimen'], test_size=0.2, random_state=42)

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.26.1-py3-none-any.whl (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 66.8 MB/s eta 0:00:00
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.13.2-py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.2/199.2 KB 18.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers) (3.9.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers) (2.25.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (23.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 79.2 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (1.26.14)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (4.0.0)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.13.2 tokenizers-0.13.2 transformers-4.26.1

# %%
bert_tokenizer = AutoTokenizer.from_pretrained("indobenchmark/indobert-base-p2")
def tokenisasi(teks):
    encode_dict = bert_tokenizer(teks,
                                   add_special_tokens = True,
                                   max_length = 128, 
                                   padding = 'max_length',
                                   truncation = True,
                                   return_attention_mask = True,
                                   return_tensors = 'tf',)

    tokenID = encode_dict['input_ids']
    attention_mask = encode_dict['attention_mask']

    return tokenID, attention_mask

def create_input(data):
    tokenID, input_mask = [], []
    for teks in data:
        token, mask = tokenisasi(teks)
        tokenID.append(token)
        input_mask.append(mask)
    
    return [np.asarray(tokenID, dtype=np.int32).reshape(-1, 128), 
            np.asarray(input_mask, dtype=np.int32).reshape(-1, 128)]

bert_model = TFAutoModel.from_pretrained("indobenchmark/indobert-base-p2", trainable=False)
def bert(hp):
    
    #Input layer
    input_token = keras.layers.Input(shape=(128,), dtype=np.int32,
                                        name="input_token")
    input_mask = keras.layers.Input(shape=(128,), dtype=np.int32,
                                   name="input_mask")

    #hidden layer
    hid_layer = hp.Choice('hid_layer_type', ['lstm', 'dense', 'both', 'none'])

    # hidden layer dense (bert embedding -> dense -> output)
    if hid_layer == 'dense':
        bert_embedding = bert_model([input_token, input_mask])[1]
        n_hid_layer = hp.Choice('n_layer', [1, 2])

        if n_hid_layer == 1:
            hidden_0 = keras.layers.Dense(hp.Int('neuron_0', 32, 128), activation='relu',
                                        kernel_regularizer=keras.regularizers.l2(hp.Float('l2_hidden_0', .001, .1)))(bert_embedding) 
            output = keras.layers.Dense(1, activation='sigmoid',
                                        kernel_regularizer=keras.regularizers.l2(hp.Float('l2_output', .001, .1)))(hidden_0)  
        else:
            hidden_0 = keras.layers.Dense(hp.Int('neuron_0', 32, 128), activation='relu',
                                        kernel_regularizer=keras.regularizers.l2(hp.Float('l2_hidden_0', .001, .1)))(bert_embedding)
            hidden_1 = keras.layers.Dense(hp.Int('neuron_1', 32, 128), activation='relu',
                                        kernel_regularizer=keras.regularizers.l2(hp.Float('l2_hidden_1', .001, .1)))(hidden_0) 
            output = keras.layers.Dense(1, activation='sigmoid',
                                        kernel_regularizer=keras.regularizers.l2(hp.Float('l2_output', .001, .1)))(hidden_1)
    
    # hidden layer lstm (bert embedding -> lstm -> output)
    elif hid_layer == 'lstm':
        bert_embedding = bert_model([input_token, input_mask])[0]
        bidirectional = hp.Choice('lstm_bidirectional', [True, False])

        if bidirectional:
            lstm = keras.layers.Bidirectional(CuDNNLSTM(hp.Int('lstm_neuron', 32, 128),
                                                        kernel_regularizer=keras.regularizers.l2(hp.Float('l2_lstm', .001, .1))))(bert_embedding)
        else:
            lstm = CuDNNLSTM(hp.Int('lstm_neuron', 32, 128),
                             kernel_regularizer=keras.regularizers.l2(hp.Float('l2_lstm', .001, .1)))(bert_embedding)
        output = keras.layers.Dense(1, activation='sigmoid',
                                    kernel_regularizer=keras.regularizers.l2(hp.Float('l2_output', .001, .1)))(lstm)

    # hidden layer lstm + dense (bert embedding -> lstm -> dense -> output)
    elif hid_layer == 'both':
        bert_embedding = bert_model([input_token, input_mask])[0]
        lstm = keras.layers.Bidirectional(CuDNNLSTM(hp.Int('lstm_neuron', 32, 128),
                                                    kernel_regularizer=keras.regularizers.l2(hp.Float('l2_lstm', .001, .1))))(bert_embedding)
        hidden_0 = keras.layers.Dense(hp.Int('neuron_0', 32, 128), activation='relu',
                                      kernel_regularizer=keras.regularizers.l2(hp.Float('l2_hidden_0', .001, .1)))(lstm)
        output = keras.layers.Dense(1, activation='sigmoid',
                                    kernel_regularizer=keras.regularizers.l2(hp.Float('l2_output', .001, .1)))(hidden_0)

    # no hiddden layer (bert embedding -> output)
    else:
        bert_embedding = bert_model([input_token, input_mask])[1]
        output = keras.layers.Dense(1, activation='sigmoid',
                                    kernel_regularizer=keras.regularizers.l2(hp.Float('l2_output', .001, .1)))(bert_embedding)

    
    model = keras.models.Model(inputs=[input_token, input_mask], outputs=output)

    model.compile(optimizer=keras.optimizers.Adam(hp.Float('lr', 1e-3, 5e-2)), loss='binary_crossentropy', metrics=['accuracy'])
   
    return model

class ClearTrainingOutput(keras.callbacks.Callback):
    def on_train_end(*args, **kwargs):
        IPython.display.clear_output(wait = True)

early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=5,
                                           restore_best_weights=True)
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.53k [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/229k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading tf_model.h5:   0%|          | 0.00/656M [00:00<?, ?B/s]
# Some layers from the model checkpoint at indobenchmark/indobert-base-p2 were not used when initializing TFBertModel: ['nsp___cls', 'mlm___cls']
# - This IS expected if you are initializing TFBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFBertModel were initialized from the model checkpoint at indobenchmark/indobert-base-p2.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.

# %%
# !pip install keras-tuner
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting keras-tuner
#   Downloading keras_tuner-1.3.0-py3-none-any.whl (167 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.3/167.3 KB 9.5 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow>=2.0 in /usr/local/lib/python3.9/dist-packages (from keras-tuner) (2.11.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from keras-tuner) (23.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from keras-tuner) (2.25.1)
# Collecting kt-legacy
#   Downloading kt_legacy-1.0.4-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: ipython in /usr/local/lib/python3.9/dist-packages (from keras-tuner) (7.9.0)
# Requirement already satisfied: keras<2.12,>=2.11.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.0->keras-tuner) (2.11.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.0->keras-tuner) (3.19.6)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.0->keras-tuner) (3.1.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.0->keras-tuner) (15.0.6.1)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.0->keras-tuner) (1.15.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.0->keras-tuner) (3.3.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.0->keras-tuner) (57.4.0)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.0->keras-tuner) (1.22.4)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.0->keras-tuner) (4.5.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.0->keras-tuner) (1.6.3)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.0->keras-tuner) (1.4.0)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.0->keras-tuner) (2.11.2)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.0->keras-tuner) (23.3.3)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.0->keras-tuner) (1.15.0)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.0->keras-tuner) (2.11.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.0->keras-tuner) (0.2.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.0->keras-tuner) (0.31.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.0->keras-tuner) (0.4.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.0->keras-tuner) (1.51.3)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.0->keras-tuner) (2.2.0)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.9/dist-packages (from ipython->keras-tuner) (5.7.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.9/dist-packages (from ipython->keras-tuner) (4.4.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.9/dist-packages (from ipython->keras-tuner) (0.2.0)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from ipython->keras-tuner) (2.0.10)
# Requirement already satisfied: pygments in /usr/local/lib/python3.9/dist-packages (from ipython->keras-tuner) (2.6.1)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.9/dist-packages (from ipython->keras-tuner) (4.8.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.9/dist-packages (from ipython->keras-tuner) (0.7.5)
# Collecting jedi>=0.10
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 59.8 MB/s eta 0:00:00
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from requests->keras-tuner) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->keras-tuner) (1.26.14)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->keras-tuner) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->keras-tuner) (2022.12.7)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.9/dist-packages (from astunparse>=1.6.0->tensorflow>=2.0->keras-tuner) (0.38.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.9/dist-packages (from jedi>=0.10->ipython->keras-tuner) (0.8.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.9/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython->keras-tuner) (0.2.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.12,>=2.11->tensorflow>=2.0->keras-tuner) (0.6.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.12,>=2.11->tensorflow>=2.0->keras-tuner) (2.2.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.12,>=2.11->tensorflow>=2.0->keras-tuner) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.12,>=2.11->tensorflow>=2.0->keras-tuner) (2.16.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.12,>=2.11->tensorflow>=2.0->keras-tuner) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.12,>=2.11->tensorflow>=2.0->keras-tuner) (3.4.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.9/dist-packages (from pexpect->ipython->keras-tuner) (0.7.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow>=2.0->keras-tuner) (5.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow>=2.0->keras-tuner) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow>=2.0->keras-tuner) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow>=2.0->keras-tuner) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.9/dist-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow>=2.0->keras-tuner) (6.0.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.9/dist-packages (from werkzeug>=1.0.1->tensorboard<2.12,>=2.11->tensorflow>=2.0->keras-tuner) (2.1.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow>=2.0->keras-tuner) (3.15.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow>=2.0->keras-tuner) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow>=2.0->keras-tuner) (3.2.2)
# Installing collected packages: kt-legacy, jedi, keras-tuner
# Successfully installed jedi-0.18.2 keras-tuner-1.3.0 kt-legacy-1.0.4

# %%
from keras_tuner.tuners import BayesianOptimization

bert_train_data = create_input(train_data)
bert_test_data = create_input(test_data)

tuner = BayesianOptimization(bert,
                             objective = 'val_accuracy', 
                             max_trials = 25,
                             directory = 'tune',
                             project_name = 'Sentiment-BERT',
                             overwrite = True)

tuner.search(bert_train_data, train_labels,
             batch_size=256, epochs=50,
             validation_data=(bert_test_data, test_labels),
             callbacks=[early_stop, ClearTrainingOutput()])
# Out:
# Trial 25 Complete [00h 07m 09s]
# val_accuracy: 0.8275862336158752
#
# Best val_accuracy So Far: 0.8514589071273804
# Total elapsed time: 03h 55m 51s

# %%
tuner.results_summary()
# Out:
# Results summary
# Results in tune/Sentiment-BERT
# Showing 10 best trials
# <keras_tuner.engine.objective.Objective object at 0x7fb6f91da160>
# Trial summary
# Hyperparameters:
# hid_layer_type: lstm
# lstm_bidirectional: 1
# lstm_neuron: 127
# l2_lstm: 0.0032251716258970705
# l2_output: 0.06278849212607956
# lr: 0.005534638759858194
# Score: 0.8514589071273804
# Trial summary
# Hyperparameters:
# hid_layer_type: lstm
# lstm_bidirectional: 1
# lstm_neuron: 50
# l2_lstm: 0.021584928051188775
# l2_output: 0.09196880065556831
# lr: 0.011835662468733413
# neuron_0: 77
# l2_hidden_0: 0.045830864494719986
# Score: 0.8381962776184082
# Trial summary
# Hyperparameters:
# hid_layer_type: both
# lstm_bidirectional: 1
# lstm_neuron: 44
# l2_lstm: 0.06044418802496354
# l2_output: 0.015050653620328022
# lr: 0.007628435985180532
# neuron_0: 103
# l2_hidden_0: 0.005753463232814367
# n_layer: 2
# Score: 0.8328912258148193
# Trial summary
# Hyperparameters:
# hid_layer_type: lstm
# lstm_bidirectional: 1
# lstm_neuron: 127
# l2_lstm: 0.01795837346561108
# l2_output: 0.06991510565543062
# lr: 0.011357654921975456
# neuron_0: 106
# l2_hidden_0: 0.04821678446590689
# n_layer: 1
# neuron_1: 58
# l2_hidden_1: 0.055550893200983456
# Score: 0.8275862336158752
# Trial summary
# Hyperparameters:
# hid_layer_type: dense
# lstm_bidirectional: 1
# lstm_neuron: 69
# l2_lstm: 0.007646928769822802
# l2_output: 0.017845328061979804
# lr: 0.001649047110135732
# neuron_0: 53
# l2_hidden_0: 0.005413168169816266
# n_layer: 1
# neuron_1: 119
# l2_hidden_1: 0.031999883489135086
# Score: 0.8222811818122864
# Trial summary
# Hyperparameters:
# hid_layer_type: none
# lstm_bidirectional: 1
# lstm_neuron: 109
# l2_lstm: 0.021760580532783035
# l2_output: 0.02205129246429318
# lr: 0.009239779459798276
# neuron_0: 124
# l2_hidden_0: 0.010708750206953516
# n_layer: 1
# neuron_1: 116
# l2_hidden_1: 0.04841497873758826
# Score: 0.7931034564971924
# Trial summary
# Hyperparameters:
# hid_layer_type: dense
# lstm_bidirectional: 0
# lstm_neuron: 90
# l2_lstm: 0.042010247118437455
# l2_output: 0.019874728149246488
# lr: 0.013976050626132316
# neuron_0: 82
# l2_hidden_0: 0.005911880299705609
# n_layer: 1
# Score: 0.7877984046936035
# Trial summary
# Hyperparameters:
# hid_layer_type: none
# lstm_bidirectional: 1
# lstm_neuron: 77
# l2_lstm: 0.07001695087213622
# l2_output: 0.04778654362604554
# lr: 0.04186022088938632
# neuron_0: 99
# l2_hidden_0: 0.06980639972227126
# n_layer: 1
# Score: 0.7851458787918091
# Trial summary
# Hyperparameters:
# hid_layer_type: none
# lstm_bidirectional: 0
# lstm_neuron: 60
# l2_lstm: 0.04861553194884162
# l2_output: 0.019965661304543327
# lr: 0.0016183776713986167
# Score: 0.7824933528900146
# Trial summary
# Hyperparameters:
# hid_layer_type: none
# lstm_bidirectional: 0
# lstm_neuron: 101
# l2_lstm: 0.03906719936899278
# l2_output: 0.0512001327293681
# lr: 0.015925609568440687
# Score: 0.7824933528900146

# %%
# Train with higher epochs
input_token = keras.layers.Input(shape=(128,), dtype=np.int32,
                                 name="input_token")
input_mask = keras.layers.Input(shape=(128,), dtype=np.int32,
                                name="input_mask")

bert_model = TFAutoModel.from_pretrained("indobenchmark/indobert-base-p2", trainable=False)
bert_embedding = bert_model([input_token, input_mask])[0]

lstm = keras.layers.Bidirectional(CuDNNLSTM(127, kernel_regularizer=keras.regularizers.l2(0.00322)))(bert_embedding)

output = keras.layers.Dense(1, activation='sigmoid', 
                            kernel_regularizer=keras.regularizers.l2(0.06278))(lstm)

model = keras.models.Model(inputs=[input_token, input_mask], outputs=output)

model.compile(optimizer=keras.optimizers.Adam(0.00553),
               loss='binary_crossentropy',
               metrics=['accuracy'])

model.summary()
# Out:
# Some layers from the model checkpoint at indobenchmark/indobert-base-p2 were not used when initializing TFBertModel: ['nsp___cls', 'mlm___cls']
# - This IS expected if you are initializing TFBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFBertModel were initialized from the model checkpoint at indobenchmark/indobert-base-p2.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_token (InputLayer)       [(None, 128)]        0           []
#
#  input_mask (InputLayer)        [(None, 128)]        0           []
#
#  tf_bert_model_7 (TFBertModel)  TFBaseModelOutputWi  124441344   ['input_token[0][0]',
#                                 thPoolingAndCrossAt               'input_mask[0][0]']
#                                 tentions(last_hidde
#                                 n_state=(None, 128,
#                                  768),
#                                  pooler_output=(Non
#                                 e, 768),
#                                  past_key_values=No
#                                 ne, hidden_states=N
#                                 one, attentions=Non
#                                 e, cross_attentions
#                                 =None)
#
#  bidirectional_7 (Bidirectional  (None, 254)         911352      ['tf_bert_model_7[0][0]']
#  )
#
#  dense_4 (Dense)                (None, 1)            255         ['bidirectional_7[0][0]']
#
# ==================================================================================================
# Total params: 125,352,951
# Trainable params: 911,607
# Non-trainable params: 124,441,344
# __________________________________________________________________________________________________

# %%
bert_train_data = create_input(train_data)
bert_test_data = create_input(test_data)

early_stop = keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=20,
                                           restore_best_weights=True)

model.fit(bert_train_data, train_labels, epochs=100, batch_size=256,
           validation_data=(bert_test_data, test_labels),
           callbacks=[early_stop])
# Out:
# Epoch 1/100
# 6/6 [==============================] - 39s 4s/step - loss: 4.0657 - accuracy: 0.6346 - val_loss: 2.6108 - val_accuracy: 0.6286
# Epoch 2/100
# 6/6 [==============================] - 20s 3s/step - loss: 2.0989 - accuracy: 0.7288 - val_loss: 1.5717 - val_accuracy: 0.7931
# Epoch 3/100
# 6/6 [==============================] - 20s 3s/step - loss: 1.3921 - accuracy: 0.7898 - val_loss: 1.1896 - val_accuracy: 0.7958
# Epoch 4/100
# 6/6 [==============================] - 20s 3s/step - loss: 1.0917 - accuracy: 0.8031 - val_loss: 0.9647 - val_accuracy: 0.8302
# Epoch 5/100
# 6/6 [==============================] - 20s 3s/step - loss: 0.8613 - accuracy: 0.8375 - val_loss: 0.7913 - val_accuracy: 0.8249
# Epoch 6/100
# 6/6 [==============================] - 20s 3s/step - loss: 0.6938 - accuracy: 0.8561 - val_loss: 0.6780 - val_accuracy: 0.8355
# Epoch 7/100
# 6/6 [==============================] - 20s 4s/step - loss: 0.5774 - accuracy: 0.8846 - val_loss: 0.6241 - val_accuracy: 0.8462
# Epoch 8/100
# 6/6 [==============================] - 18s 3s/step - loss: 0.5571 - accuracy: 0.8660 - val_loss: 0.6044 - val_accuracy: 0.8435
# Epoch 9/100
# 6/6 [==============================] - 20s 3s/step - loss: 0.5041 - accuracy: 0.8859 - val_loss: 0.5900 - val_accuracy: 0.8329
# Epoch 10/100
# 6/6 [==============================] - 19s 3s/step - loss: 0.4559 - accuracy: 0.9098 - val_loss: 0.5918 - val_accuracy: 0.8382
# Epoch 11/100
# 6/6 [==============================] - 19s 3s/step - loss: 0.4441 - accuracy: 0.9005 - val_loss: 0.6358 - val_accuracy: 0.8196
# Epoch 12/100
# 6/6 [==============================] - 20s 3s/step - loss: 0.4205 - accuracy: 0.9218 - val_loss: 0.5964 - val_accuracy: 0.8541
# Epoch 13/100
# 6/6 [==============================] - 18s 3s/step - loss: 0.3856 - accuracy: 0.9370 - val_loss: 0.5904 - val_accuracy: 0.8568
# Epoch 14/100
# 6/6 [==============================] - 20s 4s/step - loss: 0.3635 - accuracy: 0.9390 - val_loss: 0.5498 - val_accuracy: 0.8594
# Epoch 15/100
# 6/6 [==============================] - 19s 3s/step - loss: 0.3577 - accuracy: 0.9403 - val_loss: 0.5713 - val_accuracy: 0.8515
# Epoch 16/100
# 6/6 [==============================] - 19s 3s/step - loss: 0.3618 - accuracy: 0.9297 - val_loss: 0.6075 - val_accuracy: 0.8462
# Epoch 17/100
# 6/6 [==============================] - 19s 3s/step - loss: 0.3641 - accuracy: 0.9344 - val_loss: 0.5721 - val_accuracy: 0.8435
# Epoch 18/100
# 6/6 [==============================] - 18s 3s/step - loss: 0.3416 - accuracy: 0.9569 - val_loss: 0.6265 - val_accuracy: 0.8408
# Epoch 19/100
# 6/6 [==============================] - 20s 3s/step - loss: 0.3455 - accuracy: 0.9509 - val_loss: 0.6592 - val_accuracy: 0.8223
# Epoch 20/100
# 6/6 [==============================] - 19s 3s/step - loss: 0.3379 - accuracy: 0.9589 - val_loss: 0.6402 - val_accuracy: 0.8382
# Epoch 21/100
# 6/6 [==============================] - 19s 3s/step - loss: 0.3499 - accuracy: 0.9509 - val_loss: 0.7495 - val_accuracy: 0.8276
# Epoch 22/100
# 6/6 [==============================] - 20s 3s/step - loss: 0.3899 - accuracy: 0.9383 - val_loss: 0.6006 - val_accuracy: 0.8621
# Epoch 23/100
# 6/6 [==============================] - 20s 4s/step - loss: 0.3471 - accuracy: 0.9615 - val_loss: 0.5592 - val_accuracy: 0.8753
# Epoch 24/100
# 6/6 [==============================] - 18s 3s/step - loss: 0.3137 - accuracy: 0.9682 - val_loss: 0.5546 - val_accuracy: 0.8700
# Epoch 25/100
# 6/6 [==============================] - 20s 3s/step - loss: 0.2908 - accuracy: 0.9801 - val_loss: 0.6175 - val_accuracy: 0.8594
# Epoch 26/100
# 6/6 [==============================] - 19s 3s/step - loss: 0.2960 - accuracy: 0.9748 - val_loss: 0.6451 - val_accuracy: 0.8355
# Epoch 27/100
# 6/6 [==============================] - 19s 3s/step - loss: 0.3288 - accuracy: 0.9562 - val_loss: 0.5887 - val_accuracy: 0.8727
# Epoch 28/100
# 6/6 [==============================] - 19s 3s/step - loss: 0.3395 - accuracy: 0.9509 - val_loss: 0.6038 - val_accuracy: 0.8462
# Epoch 29/100
# 6/6 [==============================] - 19s 3s/step - loss: 0.3022 - accuracy: 0.9695 - val_loss: 0.6122 - val_accuracy: 0.8515
# Epoch 30/100
# 6/6 [==============================] - 20s 3s/step - loss: 0.3156 - accuracy: 0.9595 - val_loss: 0.6014 - val_accuracy: 0.8488
# Epoch 31/100
# 6/6 [==============================] - 18s 3s/step - loss: 0.3216 - accuracy: 0.9576 - val_loss: 0.6363 - val_accuracy: 0.8515
# Epoch 32/100
# 6/6 [==============================] - 18s 3s/step - loss: 0.3088 - accuracy: 0.9635 - val_loss: 0.6152 - val_accuracy: 0.8515
# Epoch 33/100
# 6/6 [==============================] - 20s 3s/step - loss: 0.3162 - accuracy: 0.9569 - val_loss: 0.6141 - val_accuracy: 0.8568
# Epoch 34/100
# 6/6 [==============================] - 19s 3s/step - loss: 0.2943 - accuracy: 0.9688 - val_loss: 0.6026 - val_accuracy: 0.8568
# Epoch 35/100
# 6/6 [==============================] - 18s 3s/step - loss: 0.2992 - accuracy: 0.9662 - val_loss: 0.5575 - val_accuracy: 0.8780
# Epoch 36/100
# 6/6 [==============================] - 20s 3s/step - loss: 0.3062 - accuracy: 0.9649 - val_loss: 0.5958 - val_accuracy: 0.8488
# Epoch 37/100
# 6/6 [==============================] - 19s 3s/step - loss: 0.3038 - accuracy: 0.9721 - val_loss: 0.6091 - val_accuracy: 0.8780
# Epoch 38/100
# 6/6 [==============================] - 18s 3s/step - loss: 0.2943 - accuracy: 0.9741 - val_loss: 0.5871 - val_accuracy: 0.8647
# Epoch 39/100
# 6/6 [==============================] - 20s 3s/step - loss: 0.2874 - accuracy: 0.9775 - val_loss: 0.5909 - val_accuracy: 0.8568
# Epoch 40/100
# 6/6 [==============================] - 20s 3s/step - loss: 0.2554 - accuracy: 0.9834 - val_loss: 0.5656 - val_accuracy: 0.8806
# Epoch 41/100
# 6/6 [==============================] - 19s 3s/step - loss: 0.2692 - accuracy: 0.9781 - val_loss: 0.5623 - val_accuracy: 0.8674
# Epoch 42/100
# 6/6 [==============================] - 20s 3s/step - loss: 0.2784 - accuracy: 0.9728 - val_loss: 0.5869 - val_accuracy: 0.8700
# Epoch 43/100
# 6/6 [==============================] - 18s 3s/step - loss: 0.2526 - accuracy: 0.9834 - val_loss: 0.5758 - val_accuracy: 0.8727
# Epoch 44/100
# 6/6 [==============================] - 20s 3s/step - loss: 0.2870 - accuracy: 0.9675 - val_loss: 0.5947 - val_accuracy: 0.8647
# Epoch 45/100
# 6/6 [==============================] - 18s 3s/step - loss: 0.2774 - accuracy: 0.9768 - val_loss: 0.6646 - val_accuracy: 0.8594
# Epoch 46/100
# 6/6 [==============================] - 19s 3s/step - loss: 0.2856 - accuracy: 0.9781 - val_loss: 0.6834 - val_accuracy: 0.8568
# Epoch 47/100
# 6/6 [==============================] - 19s 3s/step - loss: 0.3329 - accuracy: 0.9529 - val_loss: 0.5817 - val_accuracy: 0.8674
# Epoch 48/100
# 6/6 [==============================] - 19s 3s/step - loss: 0.3139 - accuracy: 0.9642 - val_loss: 0.5645 - val_accuracy: 0.8674
# Epoch 49/100
# 6/6 [==============================] - 20s 3s/step - loss: 0.2886 - accuracy: 0.9768 - val_loss: 0.6047 - val_accuracy: 0.8753
# Epoch 50/100
# 6/6 [==============================] - 19s 3s/step - loss: 0.2885 - accuracy: 0.9721 - val_loss: 0.5913 - val_accuracy: 0.8621
# Epoch 51/100
# 6/6 [==============================] - 19s 3s/step - loss: 0.2787 - accuracy: 0.9775 - val_loss: 0.6734 - val_accuracy: 0.8462
# Epoch 52/100
# 6/6 [==============================] - 20s 3s/step - loss: 0.2807 - accuracy: 0.9788 - val_loss: 0.6351 - val_accuracy: 0.8621
# Epoch 53/100
# 6/6 [==============================] - 18s 3s/step - loss: 0.2936 - accuracy: 0.9735 - val_loss: 0.5810 - val_accuracy: 0.8780
# Epoch 54/100
# 6/6 [==============================] - 20s 3s/step - loss: 0.2760 - accuracy: 0.9788 - val_loss: 0.6352 - val_accuracy: 0.8621
# Epoch 55/100
# 6/6 [==============================] - 19s 3s/step - loss: 0.2472 - accuracy: 0.9854 - val_loss: 0.6704 - val_accuracy: 0.8647
# Epoch 56/100
# 6/6 [==============================] - 20s 3s/step - loss: 0.3451 - accuracy: 0.9443 - val_loss: 0.5827 - val_accuracy: 0.8382
# Epoch 57/100
# 6/6 [==============================] - 19s 3s/step - loss: 0.3287 - accuracy: 0.9582 - val_loss: 0.6415 - val_accuracy: 0.8488
# Epoch 58/100
# 6/6 [==============================] - 19s 3s/step - loss: 0.2945 - accuracy: 0.9682 - val_loss: 0.6049 - val_accuracy: 0.8594
# Epoch 59/100
# 6/6 [==============================] - 19s 3s/step - loss: 0.2993 - accuracy: 0.9688 - val_loss: 0.6091 - val_accuracy: 0.8674
# Epoch 60/100
# 6/6 [==============================] - 20s 3s/step - loss: 0.3021 - accuracy: 0.9629 - val_loss: 0.5960 - val_accuracy: 0.8541

# %%
model.save('/content/drive/MyDrive/Colab Notebooks/model_mlp_sentiment_8806.h5')

# %%
model = keras.models.load_model('/content/drive/MyDrive/Colab Notebooks/model_mlp_sentiment_8806.h5',
                                 custom_objects={"TFBertModel": TFBertModel})

model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_token (InputLayer)       [(None, 128)]        0           []
#
#  input_mask (InputLayer)        [(None, 128)]        0           []
#
#  tf_bert_model_10 (TFBertModel)  TFBaseModelOutputWi  124441344  ['input_token[0][0]',
#                                 thPoolingAndCrossAt               'input_mask[0][0]']
#                                 tentions(last_hidde
#                                 n_state=(None, 128,
#                                  768),
#                                  pooler_output=(Non
#                                 e, 768),
#                                  past_key_values=No
#                                 ne, hidden_states=N
#                                 one, attentions=Non
#                                 e, cross_attentions
#                                 =None)
#
#  bidirectional_7 (Bidirectional  (None, 254)         911352      ['tf_bert_model_10[0][0]']
#  )
#
#  dense_4 (Dense)                (None, 1)            255         ['bidirectional_7[0][0]']
#
# ==================================================================================================
# Total params: 125,352,951
# Trainable params: 125,352,951
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
test_loss, test_acc = model.evaluate(bert_test_data, test_labels)
print('Test accuracy:', test_acc)
# Out:
# 12/12 [==============================] - 7s 290ms/step - loss: 0.5656 - accuracy: 0.8806
# Test accuracy: 0.8806366324424744
